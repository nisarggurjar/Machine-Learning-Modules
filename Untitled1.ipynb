# %%
import pandas as pd
import numpy as np

# %%
df.loc(df['spattack']>80)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-483194720e6d> in <module>
# ----> 1 df.loc(df['sp_attack']>80)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in __call__(self, axis)
#     100
#     101         if axis is not None:
# --> 102             axis = self.obj._get_axis_number(axis)
#     103         new_self.axis = axis
#     104         return new_self
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in _get_axis_number(cls, axis)
#     349     @classmethod
#     350     def _get_axis_number(cls, axis):
# --> 351         axis = cls._AXIS_ALIASES.get(axis, axis)
#     352         if is_integer(axis):
#     353             if axis in cls._AXIS_NAMES:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __hash__(self)
#    1814     def __hash__(self):
# ...

# %%
df.loc[(df['type1']=='grass') & (df['type2']=='poison') & (df['hp']>70)]
#print(d1.loc[df['type2']=='poison'].name)
# Out:
#                            abilities  against_bug  against_dark  \
# 2        ['Overgrow', 'Chlorophyll']          1.0           1.0
# 44   ['Chlorophyll', 'Effect Spore']          1.0           1.0
# 70       ['Chlorophyll', 'Gluttony']          1.0           1.0
# 590  ['Effect Spore', 'Regenerator']          1.0           1.0
#
#      against_dragon  against_electric  against_fairy  against_fight  \
# 2               1.0               0.5            0.5            0.5
# 44              1.0               0.5            0.5            0.5
# 70              1.0               0.5            0.5            0.5
# 590             1.0               0.5            0.5            0.5
#
#      against_fire  against_flying  against_ghost  ...  percentage_male  \
# 2             2.0             2.0            1.0  ...             88.1
# 44            2.0             2.0            1.0  ...             50.0
# 70            2.0             2.0            1.0  ...             50.0
# ...

# %%
df = df.reset_index()

# %%
df = pd.read_csv('pokemon.csv')

# %%
df.sort_values('name', inplace = True)
# Out:
#      index                                      abilities  against_bug  \
# 0      459                 ['Snow Warning', 'Soundproof']         2.00
# 1       62  ['Synchronize', 'Inner Focus', 'Magic Guard']         2.00
# 2      358        ['Pressure', 'Super Luck', 'Justified']         2.00
# 3      616       ['Hydration', 'Sticky Hold', 'Unburden']         1.00
# 4      680                              ['Stance Change']         0.25
# 5      141           ['Rock Head', 'Pressure', 'Unnerve']         0.50
# 6      305         ['Sturdy', 'Rock Head', 'Heavy Metal']         0.50
# 7      189           ['Run Away', 'Pickup', 'Skill Link']         1.00
# 8       64  ['Synchronize', 'Inner Focus', 'Magic Guard']         2.00
# 9      593         ['Healer', 'Hydration', 'Regenerator']         1.00
# 10     333                 ['Natural Cure', 'Cloud Nine']         0.50
# 11     697                ['Refrigerate', 'Snow Warning']         1.00
# ...

# %%
import re

# %%
df.loc[df['name'].str.contains('mega')].name
# Out:
# 788    Yanmega
# Name: name, dtype: object

# %%
df.loc[df['type1']=='grass', ['generation',	'is_legendary']]=[12,False]

# %%
df.groupby(['type1']).sort_value('speed')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-84-ec40110b04ab> in <module>
# ----> 1 df.groupby(['type1']).sort_value('speed')
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in __getattr__(self, attr)
#     534
#     535         raise AttributeError("%r object has no attribute %r" %
# --> 536                              (type(self).__name__, attr))
#     537
#     538     @Substitution(klass='GroupBy',
#
# AttributeError: 'DataFrameGroupBy' object has no attribute 'sort_value'

# %%
for df in pd.read_csv('pokemon.csv',chunksize=5):
    print('CHUNK')
    print(df)
# Out:
# CHUNK
#                      abilities  against_bug  against_dark  against_dragon  \
# 0  ['Overgrow', 'Chlorophyll']          1.0             1               1
# 1  ['Overgrow', 'Chlorophyll']          1.0             1               1
# 2  ['Overgrow', 'Chlorophyll']          1.0             1               1
# 3     ['Blaze', 'Solar Power']          0.5             1               1
# 4     ['Blaze', 'Solar Power']          0.5             1               1
#
#    against_electric  against_fairy  against_fight  against_fire  \
# 0               0.5            0.5            0.5           2.0
# 1               0.5            0.5            0.5           2.0
# 2               0.5            0.5            0.5           2.0
# 3               1.0            0.5            1.0           0.5
# 4               1.0            0.5            1.0           0.5
#
#    against_flying  against_ghost  ...  percentage_male  pokedex_number  \
# ...
